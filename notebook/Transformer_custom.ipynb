# %% [markdown]
# #Drive mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Install

# %%
# # =========Tokenizers=========
# # Janome
# !pip install janome
# # Mecab
# #インストール
# !pip install mecab-python3
# #辞書インストール
# !pip install unidic-lite
# Out:
# Collecting janome
#   Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 37.6 MB/s eta 0:00:00
# Installing collected packages: janome
# Successfully installed janome-0.5.0
# Collecting mecab-python3
#   Downloading mecab_python3-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (581 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.7/581.7 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-1.0.8
# Collecting unidic-lite
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 27.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: unidic-lite
#   Building wheel for unidic-lite (setup.py) ... done
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658818 sha256=b0d20fc4a898afd4529a7c99d9af17b1175a572cff522334ff940a29a1bcf264
#   Stored in directory: /root/.cache/pip/wheels/89/e8/68/f9ac36b8cc6c8b3c96888cd57434abed96595d444f42243853
# Successfully built unidic-lite
# Installing collected packages: unidic-lite
# Successfully installed unidic-lite-1.0.8

# %% [markdown]
# # Import

# %%
import os
import MeCab
import janome
from janome.tokenizer import Tokenizer
import spacy
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import Counter
from itertools import chain
from torchtext.vocab import vocab
import torchtext.transforms as T
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, Tensor
import torch.optim as optim
import math

# %% [markdown]
# # Configs

# %%
DEVICE = "cuda"
BATCH_SIZE = 8
MAX_LEN = 16
EMBEDDING_DIMENSION = 512
ATTENTION_HEADER_NUM = 8

# %% [markdown]
# # Load data

# %%
os.chdir("/content/drive/MyDrive/git_project/Transformers")
df = pd.read_excel("./data/JEC_basic_sentence_v1-3/JEC_basic_sentence_v1-3.xls", header = None)

train_df, valid_df = train_test_split(df, test_size=0.2)

# %%
train_data = train_df[1].tolist()
train_target = train_df[2].tolist()

valid_data = valid_df[1].tolist()
valid_target = valid_df[2].tolist()

print(f"train len:{len(train_data)} valid len:{len(valid_data)}")
# Out:
# train len:4243 valid len:1061

# %% [markdown]
# # Define Tokenizers

# %%
# Japanese Tokenizers
mecab = MeCab.Tagger("-Owakati")
janome = Tokenizer()

def jp_tokenizer(text, tokenizer="mecab"):
    if tokenizer == "mecab":
        return mecab.parse(text).split()
    elif tokenizer == "janome":
        return [tok for tok in janome.tokenize(text, wakati=True)]
    else:
        raise Exception("Undefined jp tokenizer")

# English Tokenizers
en_spacy = spacy.load('en_core_web_sm')

def en_tokenize(text, tokenizer="spacy"):
    if tokenizer == "spacy":
        return [t.text for t in en_spacy.tokenizer(text)]
    else:
        raise Exception("Undefined en tokenizer")

tokenized_train_data = [jp_tokenizer(data) for data in train_data]
tokenized_target_data = [en_tokenize(data) for data in train_target]

# %% [markdown]
# # Define vocab

# %%
jp_counter = Counter()
jp_counter.update(chain(*tokenized_train_data))
jp_vocab = vocab(jp_counter, specials=(["<unk>", "<pad>", "<bos>", "<eos>"]))
jp_vocab.set_default_index(jp_vocab["<unk>"])

en_counter = Counter()
en_counter.update(chain(*tokenized_target_data))
en_vocab = vocab(en_counter, specials=(["<unk>", "<pad>", "<bos>", "<eos>"]))
en_vocab.set_default_index(en_vocab["<unk>"])

# %% [markdown]
# # Define text transformer

# %%
text_max_len = MAX_LEN - 2

jp_text_transform = T.Sequential(
  T.VocabTransform(jp_vocab),
  T.Truncate(text_max_len),
  T.AddToken(token=jp_vocab['<bos>'], begin=True),
  T.AddToken(token=jp_vocab['<eos>'], begin=False),
  T.ToTensor(),
  T.PadTransform(MAX_LEN, jp_vocab['<pad>'])
)

en_text_transform = T.Sequential(
  T.VocabTransform(en_vocab),
  T.Truncate(text_max_len),
  T.AddToken(token=en_vocab['<bos>'], begin=True),
  T.AddToken(token=en_vocab['<eos>'], begin=False),
  T.ToTensor(),
  T.PadTransform(MAX_LEN, en_vocab['<pad>'])
)

# %% [markdown]
# # Define dataset

# %%
class Dataset(Dataset):
    def __init__(
        self,
        texts,
        targets,
        jp_text_transform,
        en_text_transform,
        ):

        self.texts = texts
        self.targets = targets
        self.jp_text_transform = jp_text_transform
        self.en_text_transform = en_text_transform
        self.build()

    def build(self):
        self.texts = [jp_tokenizer(data) for data in self.texts]
        self.targets = [jp_tokenizer(data) for data in self.targets]

    def max_word(self):
        return len(self.j_v), len(self.e_v)

    def __getitem__(self, i):
        text = self.texts[i]
        original_text = text
        text = self.jp_text_transform([text]).squeeze()

        target = self.targets[i]
        target = self.en_text_transform([target]).squeeze()


        # dec input should be started by <bos>
        dec_input = target[:-1]
        dec_target = target[1:]
        data = {"text": text, "dec_input": dec_input, "dec_target": dec_target}
        return data

    def __len__(self):
        return len(self.texts)

# %%
train_dataset = Dataset(
    train_data,
    train_target,
    jp_text_transform,
    en_text_transform
)
train_data_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          num_workers=4,
                          drop_last=True,
                          shuffle=False)

# %% [markdown]
# # Define model architecture

# %%
# https://qiita.com/gensal/items/e1c4a34dbfd0d7449099
class PositionalEncoding(nn.Module):

  def __init__(self, dim, dropout = 0.1, max_len = 5000):
    super().__init__()
    self.dropout = nn.Dropout(p=dropout)
    position = torch.arange(max_len).unsqueeze(1).to(DEVICE)
    div_term = torch.exp(torch.arange(0, dim, 2) * (-math.log(10000.0) / dim)).to(DEVICE)
    pe = torch.zeros(max_len, 1, dim).to(DEVICE)
    pe[:, 0, 0::2] = torch.sin(position * div_term)
    pe[:, 0, 1::2] = torch.cos(position * div_term)
    self.register_buffer("pe", pe)

  def forward(self, x):
    x = x + self.pe[:x.size(0)]
    return self.dropout(x)

class MultiHeadAttention(nn.Module):

  def __init__(self, dim, head_num, dropout = 0.1):
    super().__init__()
    self.dim = dim
    self.head_num = head_num
    self.linear_Q = nn.Linear(dim, dim, bias = False)
    self.linear_K = nn.Linear(dim, dim, bias = False)
    self.linear_V = nn.Linear(dim, dim, bias = False)
    self.linear = nn.Linear(dim, dim, bias = False)
    self.soft = nn.Softmax(dim = 3)
    self.dropout = nn.Dropout(dropout)

  def split_head(self, x):
    x = torch.tensor_split(x, self.head_num, dim = 2)
    x = torch.stack(x, dim = 1)
    return x

  def concat_head(self, x):
    x = torch.tensor_split(x, x.size()[1], dim = 1)
    x = torch.concat(x, dim = 3).squeeze(dim = 1)
    return x

  def forward(self, Q, K, V, mask = None):
    Q = self.linear_Q(Q)   #(BATCH_SIZE,word_count,dim)
    K = self.linear_K(K)
    V = self.linear_V(V)

    Q = self.split_head(Q)   #(BATCH_SIZE,head_num,word_count,dim//head_num)
    K = self.split_head(K)
    V = self.split_head(V)

    QK = torch.matmul(Q, torch.transpose(K, 3, 2))
    QK = QK/((self.dim//self.head_num)**0.5)

    if mask is not None:
      QK = QK + mask

    softmax_QK = self.soft(QK)
    softmax_QK = self.dropout(softmax_QK)

    QKV = torch.matmul(softmax_QK, V)
    QKV = self.concat_head(QKV)
    QKV = self.linear(QKV)
    return QKV

class FeedForward(nn.Module):

  def __init__(self, dim, hidden_dim = 2048, dropout = 0.1):
    super().__init__()
    self.dropout = nn.Dropout(dropout)
    self.linear_1 = nn.Linear(dim, hidden_dim)
    self.relu = nn.ReLU()
    self.linear_2 = nn.Linear(hidden_dim, dim)

  def forward(self, x):
    x = self.linear_1(x)
    x = self.relu(x)
    x = self.dropout(x)
    x = self.linear_2(x)
    return x

class EncoderBlock(nn.Module):

  def __init__(self, dim, head_num, dropout = 0.1):
    super().__init__()
    self.MHA = MultiHeadAttention(dim, head_num)
    self.layer_norm_1 = nn.LayerNorm([dim])
    self.layer_norm_2 = nn.LayerNorm([dim])
    self.FF = FeedForward(dim)
    self.dropout_1 = nn.Dropout(dropout)
    self.dropout_2 = nn.Dropout(dropout)

  def forward(self, x):
    Q = K = V = x
    x = self.MHA(Q, K, V)
    x = self.dropout_1(x)
    x = x + Q
    x = self.layer_norm_1(x)
    _x = x
    x = self.FF(x)
    x = self.dropout_2(x)
    x = x + _x
    x = self.layer_norm_2(x)
    return x

class Encoder(nn.Module):

  def __init__(self, enc_vocab_size, dim, head_num, dropout = 0.1):
    super().__init__()
    self.dim = dim
    self.embed = nn.Embedding(enc_vocab_size, dim)
    self.PE = PositionalEncoding(dim)
    self.dropout = nn.Dropout(dropout)
    self.EncoderBlocks = nn.ModuleList([EncoderBlock(dim, head_num) for _ in range(6)])

  def forward(self, x):
    x = self.embed(x)
    x = x*(self.dim**0.5)
    x = self.PE(x)
    x = self.dropout(x)
    for i in range(6):
      x = self.EncoderBlocks[i](x)
    return x

class DecoderBlock(nn.Module):

  def __init__(self, dim, head_num, dropout = 0.1):
    super().__init__()
    self.MMHA = MultiHeadAttention(dim, head_num)
    self.MHA = MultiHeadAttention(dim, head_num)
    self.layer_norm_1 = nn.LayerNorm([dim])
    self.layer_norm_2 = nn.LayerNorm([dim])
    self.layer_norm_3 = nn.LayerNorm([dim])
    self.FF = FeedForward(dim)
    self.dropout_1 = nn.Dropout(dropout)
    self.dropout_2 = nn.Dropout(dropout)
    self.dropout_3 = nn.Dropout(dropout)

  def forward(self, x, y, mask):
    Q = K = V = x
    x = self.MMHA(Q, K, V, mask)
    x = self.dropout_1(x)
    x = x + Q
    x = self.layer_norm_1(x)
    Q = x
    K = V = y
    x = self.MHA(Q, K, V)
    x = self.dropout_2(x)
    x = x + Q
    x = self.layer_norm_2(x)
    _x = x
    x = self.FF(x)
    x = self.dropout_3(x)
    x = x + _x
    x = self.layer_norm_3(x)
    return x

class Decoder(nn.Module):

  def __init__(self, dec_vocab_size, dim, head_num, dropout = 0.1):
    super().__init__()
    self.dim = dim
    self.embed = nn.Embedding(dec_vocab_size, dim)
    self.PE = PositionalEncoding(dim)
    self.DecoderBlocks = nn.ModuleList([DecoderBlock(dim, head_num) for _ in range(6)])
    self.dropout = nn.Dropout(dropout)
    self.linear = nn.Linear(dim, dec_vocab_size)

  def forward(self, x, y, mask):
    x = self.embed(x)
    x = x*(self.dim**0.5)
    x = self.PE(x)
    x = self.dropout(x)
    for i in range(6):
      x = self.DecoderBlocks[i](x, y, mask)
    x = self.linear(x)
    return x

class Transformer(nn.Module):

  def __init__(self, enc_vocab_size, dec_vocab_size, dim, head_num):
    super().__init__()
    self.encoder = Encoder(enc_vocab_size, dim, head_num)
    self.decoder = Decoder(dec_vocab_size, dim, head_num)

  def forward(self, enc_input, dec_input, mask):
    enc_output = self.encoder(enc_input)
    output = self.decoder(dec_input, enc_output, mask)
    return output

# %% [markdown]
# # Load Dataset & DataLoader

# %%
train_dataset = Dataset(
    train_data,
    train_target,
    jp_text_transform,
    en_text_transform
)
train_data_loader = DataLoader(train_dataset,
                          batch_size=BATCH_SIZE,
                          num_workers=4,
                          drop_last=True,
                          shuffle=False)

# data = next(iter(train_data_loader))
# text, dec_input, target = data["text"], data["dec_input"], data["dec_target"]
# print(text[0], dec_input[0], target[0], sep="\n")

valid_dataset = Dataset(
    valid_data,
    valid_target,
    jp_text_transform,
    en_text_transform
)
valid_data_loader = DataLoader(valid_dataset,
                          batch_size=BATCH_SIZE,
                          num_workers=4,
                          drop_last=True,
                          shuffle=False)

# %% [markdown]
# # Define tranlate function

# %%
def translate(texts):
    max_len = MAX_LEN
    texts = texts.to(DEVICE)
    memory = model.encoder(texts)
    ys = torch.ones(len(texts), 1).fill_(jp_vocab['<bos>']).type(torch.long).to(DEVICE)
    for i in range(max_len-1):
        memory = memory.to(DEVICE)
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(ys.size(1)).to(DEVICE)
        out = model.decoder(ys, memory, tgt_mask)

        pred = out[:,-1].argmax(dim=1)
        ys = torch.cat([ys, pred.unsqueeze(1)], dim=1)
    text_outputs = []
    for toks in ys.detach().cpu().numpy().tolist():
        text_outputs.append(" ".join(en_vocab.lookup_tokens(toks)))
    return text_outputs

# %% [markdown]
# # Train

# %%
model = Transformer(len(jp_vocab), len(en_vocab), dim = EMBEDDING_DIMENSION, head_num = ATTENTION_HEADER_NUM).to(DEVICE)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

epoch_num = 200
print_coef = 10
train_length = len(train_dataset)

history = {"train_loss": []}
n = 0
train_loss = 0

except_token = [1,2,3]
for epoch in range(epoch_num):

    for i, data in enumerate(train_data_loader):
        model.train()
        optimizer.zero_grad()
        text, dec_input, target = data["text"].to(DEVICE), data["dec_input"].to(DEVICE), data["dec_target"].to(DEVICE)
        mask = nn.Transformer.generate_square_subsequent_mask(MAX_LEN - 2 + 1).to(DEVICE)

        outputs = model(text, dec_input, mask)
        target = nn.functional.one_hot(target, len(en_vocab)).to(torch.float32)

        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        history["train_loss"].append(loss.item())
        n += 1
        if i % ((train_length//BATCH_SIZE)//print_coef) == (train_length//BATCH_SIZE)//print_coef - 1:
            print(f"epoch:{epoch+1}  index:{i+1}  loss:{train_loss/n:.10f}")
            train_loss = 0
            n = 0

            # just one sample validation
            model.eval()
            for i, data in enumerate(train_data_loader):
                with torch.no_grad():
                    text, dec_input, target = data["text"].to(DEVICE), data["dec_input"].to(DEVICE), data["dec_target"].to(DEVICE)
                    mask = nn.Transformer.generate_square_subsequent_mask(MAX_LEN - 2 + 1).to(DEVICE)
                    outputs = model(text, dec_input, mask)
                    pred = torch.argmax(outputs, dim=2)
                    input_token = text[0].detach().cpu().numpy().tolist()
                    input_token = [t for t in input_token if t not in except_token]
                    input_text = "".join(jp_vocab.lookup_tokens(input_token))

                    target_token = target[0].detach().cpu().numpy().tolist()
                    target_token = [t for t in target_token if t not in except_token]
                    target_text = " ".join(en_vocab.lookup_tokens(target_token))

                    output_text = translate(text)[0]

                    print(f"input_text:{input_text},\n target_text:{target_text},\n output_text:{output_text}")
                break
# Out:
# epoch:1  index:53  loss:0.0055686241
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will was finally was the consulting . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:106  loss:0.0050161803
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will a lot of the first . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:159  loss:0.0047984165
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be a lot of the first . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:212  loss:0.0046845753
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be a lot of . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:265  loss:0.0044649337
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be a lot of the first . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:318  loss:0.0044251539
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be a lot of the first . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:371  loss:0.0042233812
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will go his a lot of X . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:424  loss:0.0041987485
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be held in the first time . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:1  index:477  loss:0.0040513281
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be a lot of the following X . <eos> <pad> <pad> <pad> <pad>
# epoch:1  index:530  loss:0.0039875714
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He has a lot of X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:2  index:53  loss:0.0037320917
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He has been very many a lot of the same . <eos> <pad> <pad> <pad>
# epoch:2  index:106  loss:0.0036983283
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will never all over the first time in my own . <eos> <pad> <pad>
# epoch:2  index:159  loss:0.0036162131
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be a lot of the first time . <eos> <pad> <pad> <pad> <pad>
# epoch:2  index:212  loss:0.0036251377
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be used for a lot of . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:2  index:265  loss:0.0035157134
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be already been a lot of X . <eos> <pad> <pad> <pad> <pad>
# epoch:2  index:318  loss:0.0035271083
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will be used on the same <unk> . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:2  index:371  loss:0.0033990772
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He will never been a lot of the first time . <eos> <pad> <pad> <pad>
# epoch:2  index:424  loss:0.0034233399
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He has been made a lot of the following that time . <eos> <pad> <pad>
# epoch:2  index:477  loss:0.0033230722
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He was already a lot of X . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:2  index:530  loss:0.0032813775
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took my own is in the world . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:3  index:53  loss:0.0031032007
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your skin on X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:3  index:106  loss:0.0030944262
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people who are shown in X . <eos> <pad> <pad> <pad> <pad>
# epoch:3  index:159  loss:0.0030083248
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took a lot of X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:3  index:212  loss:0.0030647064
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people in the same time . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:3  index:265  loss:0.0029788618
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took not be used for the first time . <eos> <pad> <pad> <pad> <pad>
# epoch:3  index:318  loss:0.0029775459
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took not come in the same time . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:3  index:371  loss:0.0028869734
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your help with X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:3  index:424  loss:0.0029327364
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people who is always in a lot of the following . <eos>
# epoch:3  index:477  loss:0.0028557231
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his head to the following of a lot . <eos> <pad> <pad> <pad>
# epoch:3  index:530  loss:0.0028190791
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people who are shown in the same . <eos> <pad> <pad> <pad>
# epoch:4  index:53  loss:0.0026954986
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people who are always in the same time . <eos> <pad> <pad>
# epoch:4  index:106  loss:0.0026823880
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people in the world . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:4  index:159  loss:0.0025937740
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited a lot of people on X . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:4  index:212  loss:0.0026711842
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people in the same time . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:4  index:265  loss:0.0026045215
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 his own way for the first time . <eos> <pad> <pad> <pad>
# epoch:4  index:318  loss:0.0026008513
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took not really been added with X . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:4  index:371  loss:0.0025396518
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your help with X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:4  index:424  loss:0.0025818751
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with my own way . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:4  index:477  loss:0.0025125358
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited my head that time . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:4  index:530  loss:0.0024728812
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took an certain degree of his head . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:5  index:53  loss:0.0024096332
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your skin on the same time . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:5  index:106  loss:0.0024099488
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:5  index:159  loss:0.0023042936
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited a lot of things that it . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:5  index:212  loss:0.0024108678
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people who are shown in the same time . <eos> <pad> <pad>
# epoch:5  index:265  loss:0.0023499549
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 , I will be held in the same time . <eos> <pad>
# epoch:5  index:318  loss:0.0023193895
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with my own - related . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:5  index:371  loss:0.0022944944
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your skin more than X . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:5  index:424  loss:0.0023360074
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with my own day . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:5  index:477  loss:0.0022800224
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited my head slowly in the same time . <eos> <pad> <pad> <pad> <pad>
# epoch:5  index:530  loss:0.0022336869
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took an certain I <unk> ' m not like that . <eos> <pad> <pad>
# epoch:6  index:53  loss:0.0022155914
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took an e - year for the mayor . <eos> <pad> <pad> <pad> <pad>
# epoch:6  index:106  loss:0.0022116088
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took X into the world . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:6  index:159  loss:0.0021006896
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited my mind to create the morning . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:6  index:212  loss:0.0022040474
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with the same day . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:6  index:265  loss:0.0021673857
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited my own problems . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:6  index:318  loss:0.0021397931
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with my own eyes . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:6  index:371  loss:0.0021110580
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took six the best way of X . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:6  index:424  loss:0.0021543314
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 , I will be held in the same . <eos> <pad> <pad>
# epoch:6  index:477  loss:0.0021130468
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 his head to the mayor . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:6  index:530  loss:0.0020568814
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 , I will be held in the venue . <eos> <pad> <pad>
# epoch:7  index:53  loss:0.0020679055
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with me / them . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:106  loss:0.0020802411
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took X into the world . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:159  loss:0.0019869091
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 and I ' <unk> help with the same time . <eos> <pad>
# epoch:7  index:212  loss:0.0020685019
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 his own name . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:265  loss:0.0020513260
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his own strength . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:318  loss:0.0020281317
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with his own eyes . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:371  loss:0.0019988411
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with the venue . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:424  loss:0.0020461646
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with my own day . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:477  loss:0.0020016539
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his head off at a lot . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:7  index:530  loss:0.0019375236
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 his head . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:8  index:53  loss:0.0019790736
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own eyes with the <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:8  index:106  loss:0.0019791758
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own name . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:8  index:159  loss:0.0018591872
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took a lot of things with the city . <eos> <pad> <pad> <pad> <pad>
# epoch:8  index:212  loss:0.0019834898
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people who read . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:8  index:265  loss:0.0019707139
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own problems with . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:8  index:318  loss:0.0019317250
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took six so much better in a lot of the city . <eos> <pad>
# epoch:8  index:371  loss:0.0019267271
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with his own eyes . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:8  index:424  loss:0.0019745910
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took a lot of time in the world . <eos> <pad> <pad> <pad> <pad>
# epoch:8  index:477  loss:0.0019347799
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited my head off at the morning . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:8  index:530  loss:0.0018645829
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took an explanation . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:9  index:53  loss:0.0019137905
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took an acquaintance in a lot of the world . <eos> <pad> <pad> <pad>
# epoch:9  index:106  loss:0.0019161272
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took a lot of things that . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:9  index:159  loss:0.0018008248
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took a lot of things that . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:9  index:212  loss:0.0019167778
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely took an interest in a lot of the world . <eos> <pad> <pad>
# epoch:9  index:265  loss:0.0019211160
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his hand with me . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:9  index:318  loss:0.0018773828
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 hours before the prescribed . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:9  index:371  loss:0.0018661630
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his head in the world . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:9  index:424  loss:0.0019057544
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your skin in a lot . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:9  index:477  loss:0.0018685854
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited my eyes will be held at the same time . <eos> <pad> <pad>
# epoch:9  index:530  loss:0.0018079403
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own name . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:53  loss:0.0018599216
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 his mind in the morning . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:106  loss:0.0018698835
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 my own eyes . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:159  loss:0.0017461073
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took one person on his head . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:212  loss:0.0018773210
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 % of his head to the provision . <eos> <pad> <pad> <pad>
# epoch:10  index:265  loss:0.0018719110
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own problems with the venue . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:318  loss:0.0018486329
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took many people who are especially popular with X . <eos> <pad> <pad> <pad>
# epoch:10  index:371  loss:0.0018484185
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 hours . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:424  loss:0.0018744521
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 hours . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:477  loss:0.0018466753
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own eyes to the world . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:10  index:530  loss:0.0017731438
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took three months in the world . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:11  index:53  loss:0.0018345194
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own eyes to take . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:11  index:106  loss:0.0018477724
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own eyes to the mayor . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:11  index:159  loss:0.0017417951
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own name . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:11  index:212  loss:0.0018615129
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely has made a lot of things to those who are used . <eos>
# epoch:11  index:265  loss:0.0018578716
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his hands with X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:11  index:318  loss:0.0018142554
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took put an interest rate with X . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:11  index:371  loss:0.0018096615
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your skin more than my own problems . <eos> <pad> <pad> <pad> <pad>
# epoch:11  index:424  loss:0.0018448180
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his head off at the same day . <eos> <pad> <pad> <pad> <pad>
# epoch:11  index:477  loss:0.0018116299
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his hand out the same day . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:11  index:530  loss:0.0017428941
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took three kinds of X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:53  loss:0.0018173874
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with my own eyes . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:106  loss:0.0018227330
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 with the provision and other . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:159  loss:0.0017102083
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely has made old movie in a lot of them . <eos> <pad> <pad>
# epoch:12  index:212  loss:0.0018258501
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took three months by X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:265  loss:0.0018304224
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely has made up by X . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:318  loss:0.0017909487
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely has made up on X . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:371  loss:0.0017776681
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took your own eyes to create . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:424  loss:0.0018183857
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took some sort of X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:477  loss:0.0017954557
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He visited my hands better at Koshien . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:12  index:530  loss:0.0017289468
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took an increasing number . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:13  index:53  loss:0.0018002008
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own eyes in the morning . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:13  index:106  loss:0.0018109582
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own eyes will be held . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:13  index:159  loss:0.0016942826
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 , I will be held in the world . <eos> <pad> <pad>
# epoch:13  index:212  loss:0.0017976619
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely took 3 months in the world . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:13  index:265  loss:0.0018145561
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely got his hand to create it . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:13  index:318  loss:0.0017884296
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely has never put a good impression on X . <eos> <pad> <pad> <pad>
# epoch:13  index:371  loss:0.0017628269
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 months in the world of my own . <eos> <pad> <pad> <pad>
# epoch:13  index:424  loss:0.0018133633
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 in the world . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:13  index:477  loss:0.0017772532
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He watched an interest rate into his house . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:13  index:530  loss:0.0017222757
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own name . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:14  index:53  loss:0.0017756652
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 hours with my own eyes . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:14  index:106  loss:0.0017998850
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 months in the world of his mind . <eos> <pad> <pad> <pad>
# epoch:14  index:159  loss:0.0016829859
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 his hand in the world . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:14  index:212  loss:0.0017879087
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely has made a lot of time . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:14  index:265  loss:0.0018032397
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely has been added to a lot of them . <eos> <pad> <pad> <pad>
# epoch:14  index:318  loss:0.0017752717
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 days by X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:14  index:371  loss:0.0017531892
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 his hand off at the same day . <eos> <pad> <pad> <pad>
# epoch:14  index:424  loss:0.0017979930
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 hours before the game . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:14  index:477  loss:0.0017613448
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 % through the morning . <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:14  index:530  loss:0.0017090186
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took their own name . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:15  index:53  loss:0.0017643326
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took his heart at all . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:15  index:106  loss:0.0017823642
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took two following information is . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:15  index:159  loss:0.0016657743
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 , we can be held for X . <eos> <pad> <pad> <pad>
# epoch:15  index:212  loss:0.0017779676
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He rarely took 3 % of his head . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:15  index:265  loss:0.0017885766
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 , I went through the person on . <eos> <pad> <pad> <pad>
# epoch:15  index:318  loss:0.0017685839
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 days by X . <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# epoch:15  index:371  loss:0.0017412577
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 hours before the same time . <eos> <pad> <pad> <pad> <pad> <pad>
# epoch:15  index:424  loss:0.0017941958
# input_text:彼がせっかくのチャンスを逃す,
#  target_text:He blows the chance of a lifetime,
#  output_text:<bos> He took 3 % of the people in this . <eos> <pad> <pad> <pad> <pad>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-fbf0078e7896> in <cell line: 14>()
#      24
#      25         loss = criterion(outputs, target)
# ---> 26         loss.backward()
#      27         optimizer.step()
#      28         train_loss += loss.item()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:
